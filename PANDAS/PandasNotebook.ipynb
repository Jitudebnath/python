# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({'A':[1,2,3],'B':[6,7,8]})
print(df)
# Out:
#    A  B
# 0  1  6
# 1  2  7
# 2  3  8

# %%
data={
    "Name":["Rahul","mohit","nagen","nihar","kedar"],
    "Age":[17,22,16,27,67]
}
df=pd.DataFrame(data)
df["canvote"]=np.where(df["Age"]>18,"yes,can vote","can't vote")
print(df)
# Out:
#     Name  Age       canvote
# 0  Rahul   17    can't vote
# 1  mohit   22  yes,can vote
# 2  nagen   16    can't vote
# 3  nihar   27  yes,can vote
# 4  kedar   67  yes,can vote

# %% [markdown]
# pandas is a fast,powerful,flexible and easy to use open source data
# analysis and manipulation tool,built on top of the python

# %% [markdown]
# #series
#
# A pandas series is like a column in a table . It is a 1-D array holding data of any type

# %%
countries=['India','Pakistan','USA','Nepal','SriLanka']
pd.Series(countries)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    SriLanka
# dtype: object

# %%
#integers
runs=[13,23,45,67]
pd.Series(runs,dtype='Int32')
# Out:
# 0    13
# 1    23
# 2    45
# 3    67
# dtype: Int32

# %%
#custom index
marks=[67,57,89,100]
subjects=['maths','english','science','hindi']

costum_index=pd.Series(marks,index=subjects)
print(costum_index)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
#setting a name
pd.Series(marks,index=subjects,name='Nihar ke marks ')
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Nihar ke marks , dtype: int64

# %% [markdown]
# Series from dict

# %%
marks={
    'maths':78,
    'english':89,
    'science':90,
    'hindi':99
}

marks_series=pd.Series(marks,name='jitu marks')
print(marks_series)
# Out:
# maths      78
# english    89
# science    90
# hindi      99
# Name: jitu marks, dtype: int64

# %%
#size
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#is_unique
marks_series.is_unique
# Out:
# True

# %%
#index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
#values
marks_series.values
# Out:
# array([78, 89, 90, 99])

# %% [markdown]
# Series using read_csv

# %%
#with one col
subs=pd.read_csv('subs.csv').squeeze("columns")
print(subs)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.plot(title="Subscribers per Day")
# Out:
# <Axes: title={'center': 'Subscribers per Day'}>

# %%
vk=pd.read_csv('kohli_ipl.csv',index_col="match_no").squeeze('columns')
print(vk)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk.plot(title="Kohli's performance")
# Out:
# <Axes: title={'center': "Kohli's performance"}, xlabel='match_no'>

# %%
movies=pd.read_csv('bollywood.csv',index_col='movie').squeeze('columns')
print(movies)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# series method

# %%
#head and tail
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
vk.tail(6)
# Out:
# match_no
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
#Sample random return of a sample
movies.sample()
# Out:
# movie
# Yaaram (2019 film)    Siddhanth Kapoor
# Name: lead, dtype: object

# %%
movies.sample(5)#specific value in sample
# Out:
# movie
# Haseena Parkar              Shraddha Kapoor
# Daas Dev                  Yogesh Raj Mishra
# Chicken Curry Law          Natalia Janoszek
# Thodi Life Thoda Magic        Saahil Chadha
# Naughty @ 40                        Govinda
# Name: lead, dtype: object

# %%
#value counts -> movies it returns the frequencies of the data set
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
#sort_values ->inplace
vk.sort_values(ascending=False).head(1).values
# Out:
# array([113])

# %%
#sort_index->inplace->movies for parmanent change
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# Series Maths Methods

# %%
#count, it doesnt count the missing value
total_match=vk.count()
print(total_match)
# Out:
# 215

# %%
#sum
subs.sum()
# Out:
# np.int64(49510)

# %%
#product
subs.product()
# Out:
# np.int64(0)

# %%
#mean->median->std->mode
subs.mean()
subs.mode()
# Out:
# 0    105
# Name: Subscribers gained, dtype: int64

# %%
print(vk.median())
# Out:
# 24.0

# %%
print(movies.mode())
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
print(subs.std())
# Out:
# 62.67502303725269

# %%
#min/max
print("Minimum numbers of subscribers",subs.min())
print("maximum munbers of subscribers",subs.max())
# Out:
# Minimum numbers of subscribers 33
# maximum munbers of subscribers 396

# %%
#Describe -> it provide the all mathematical details 
print(vk.describe())
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# Series indexing

# %%
#integer indexing only work on positive indexing
x=pd.Series([1,2,3,4,5,6,7,8,9])
print(x[1])
# Out:
# 2

# %%
#slicing
movies[1:9]
# Out:
# movie
# Battalion 609                                    Vicky Ahuja
# The Accidental Prime Minister (film)             Anupam Kher
# Why Cheat India                                Emraan Hashmi
# Evening Shadows                             Mona Ambegaonkar
# Soni (film)                             Geetika Vidya Ohlyan
# Fraud Saiyaan                                   Arshad Warsi
# Bombairiya                                      Radhika Apte
# Manikarnika: The Queen of Jhansi              Kangana Ranaut
# Name: lead, dtype: object

# %%
#fancy indexing (according to user need of we can use fancy index )
vk[[1,2,3,4,5]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# Editing Series

# %%
#using indexing 
marks_series[1]=100
marks_series
# Out:
# C:\Users\jitud\AppData\Local\Temp\ipykernel_1372\1461204311.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=100
# maths       78
# english    100
# science     90
# hindi       99
# Name: jitu marks, dtype: int64

# %%
marks_series
# Out:
# maths       78
# english    100
# science     90
# hindi       99
# Name: jitu marks, dtype: int64

# %%
#using index label
movies['2 states (2014-film)'] = 'Alia Bhatt'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# 2 states (2014-film)                          Alia Bhatt
# Name: lead, Length: 1501, dtype: object

# %% [markdown]
# Series with Python functionalities

# %%
#len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion
list(marks_series)
# Out:
# [78, 100, 90, 99]

# %%
dict(marks_series)
# Out:
# {'maths': np.int64(78),
#  'english': np.int64(100),
#  'science': np.int64(90),
#  'hindi': np.int64(99)}

# %%
#membership operator by default index
'baby'in movies
# Out:
# False

# %%
'alia Bhat' in movies
# Out:
# False

# %%
#looping by default values
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
#Arithematic operators
100-marks_series
# Out:
# maths      22
# english     0
# science    10
# hindi       1
# Name: jitu marks, dtype: int64

# %%
#Relational Operators

vk >=50 #return boolean series
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# Boolean Indexing on Series

# %%
#find no. of 50's and 100's scored by kohli
vk[vk>=50]
# Out:
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
#find the actors who have done more than 20 movies
num_movies=movies.value_counts()
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movies.value_counts().head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Some Important Series Methods

# %%
#astype
import sys
sys.getsizeof(vk)
# Out:
# 11768

# %%
vk.astype('int16')
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int16

# %%
#between
vk[vk.between(51,99)]
# Out:
# match_no
# 34     58
# 41     71
# 44     56
# 45     67
# 52     70
# 57     57
# 68     73
# 71     51
# 73     58
# 74     65
# 80     57
# 81     93
# 82     99
# 85     56
# 97     67
# 99     73
# 103    51
# 104    62
# 110    82
# 116    75
# 117    79
# 119    80
# 122    52
# 127    75
# 129    54
# 131    54
# 132    62
# 134    64
# 137    55
# 141    58
# 144    57
# 145    92
# 148    68
# 152    70
# 160    84
# 162    67
# 175    72
# 178    90
# 188    72
# 197    51
# 198    53
# 209    58
# 213    73
# Name: runs, dtype: int64

# %%
#clip
subs[subs.clip(100,200)]
# Out:
# 100    100
# 100    100
# 100    100
# 100    100
# 100    100
#       ...
# 200    139
# 200    139
# 155    101
# 144     86
# 172    160
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#drop_duplicates, it drop the duplicate values
temp=pd.Series([1,2,3,3,3,4,5,6,7,8,9,8,9])
temp.drop_duplicates()
# Out:
# 0     1
# 1     2
# 2     3
# 5     4
# 6     5
# 7     6
# 8     7
# 9     8
# 10    9
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
temp.duplicated()# using duplicated
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# dtype: bool

# %%
#it return how many duplicate values are there
print(temp.duplicated().sum())
# Out:
# 4

# %%
temp=pd.Series([1,2,np.nan,np.nan,3,4,5,6,7,np.nan,np.nan,8,9])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     NaN
# 3     NaN
# 4     3.0
# 5     4.0
# 6     5.0
# 7     6.0
# 8     7.0
# 9     NaN
# 10    NaN
# 11    8.0
# 12    9.0
# dtype: float64

# %%
temp.count()#it will count only not nan values
# Out:
# np.int64(9)

# %%
#isnull
print(temp.isnull().sum())
# Out:
# 4

# %%
#dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 4     3.0
# 5     4.0
# 6     5.0
# 7     6.0
# 8     7.0
# 11    8.0
# 12    9.0
# dtype: float64

# %%
#fillna , which is for filling
temp.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     0.0
# 3     0.0
# 4     3.0
# 5     4.0
# 6     5.0
# 7     6.0
# 8     7.0
# 9     0.0
# 10    0.0
# 11    8.0
# 12    9.0
# dtype: float64

# %%
#isin

vk[(vk==49) | (vk==99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
#using isin
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
#apply for using our own funtion

movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# 2 states (2014-film)                       ALIA
# Name: lead, Length: 1501, dtype: object

# %%
subs.apply(lambda x:'good day' if x> subs.mean()else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
#copy 
import pandas as pd

# Original Series
runs = pd.Series([13, 23, 45, 67], dtype="int32")

# Create a copy
runs_copy = runs.copy()

# Modify the copy
runs_copy[0] = 100

print("Original Series:")
print(runs)

print("\nCopied Series:")
print(runs_copy)
# Out:
# Original Series:
# 0    13
# 1    23
# 2    45
# 3    67
# dtype: int32
#
# Copied Series:
# 0    100
# 1     23
# 2     45
# 3     67
# dtype: int32

# %% [markdown]
# DataFrames

# %%
#tabular data is know as pandas

# %%
#data frames using python list
student_data=[[100,80,10],[90,70,7],[120,100,14],[80,50,2]]

df=pd.DataFrame(student_data,columns=['iq','marks','package'])
print(df)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
#using dicts for data sets
student_data={
    'name':['nitish','naveen','prateek'],
            'iq:':[100,80,70],
            'marks':[90,70,80],
            'package':[8,5,2]}

students=pd.DataFrame(student_data)
print(student_data)
# Out:
# {'name': ['nitish', 'naveen', 'prateek'], 'iq:': [100, 80, 70], 'marks': [90, 70, 80], 'package': [8, 5, 2]}

# %%
#using read_csv
movies=pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
pd.read_csv('ipl.csv')
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# Dataframe attributes and methods

# %%
#shape
movies.shape
# Out:
# (1629, 18)

# %%
#dtype
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
#index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
#columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
#values
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
#head
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
#tail
movies.sample(3)
# Out:
#                          title_x    imdb_id  \
# 1614          Moksha (2001 film)  tt0301240
# 393   Detective Byomkesh Bakshy!  tt3447364
# 69         Motichoor Chaknachoor  tt9172840
#
#                                             poster_path  \
# 1614  https://upload.wikimedia.org/wikipedia/en/6/6e...
# 393   https://upload.wikimedia.org/wikipedia/en/thum...
# 69    https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1614   https://en.wikipedia.org/wiki/Moksha_(2001_film)
# 393   https://en.wikipedia.org/wiki/Detective_Byomke...
# 69    https://en.wikipedia.org/wiki/Motichoor_Chakna...
#
#                          title_y              original_title  is_adult  \
# 1614           Moksha: Salvation           Moksha: Salvation         0
# 393   Detective Byomkesh Bakshy!  Detective Byomkesh Bakshy!         0
# 69         Motichoor Chaknachoor       Motichoor Chaknachoor         0
#
# ...

# %%
#info 
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#isnull
movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
#describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
movies.head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#renamefunction
students.rename(columns={'marks':'percent','package':'lpa'},inplace=True)
print(students)
# Out:
#       name  iq:  percent  lpa
# 0   nitish  100       90    8
# 1   naveen   80       70    5
# 2  prateek   70       80    2

# %% [markdown]
# Mathematical Functions

# %%
#sum ->axis argument
print(students.sum(axis=0))
# Out:
# name       nitishnaveenprateek
# iq:                        250
# percent                    240
# lpa                         15
# dtype: object

# %%
#min
students.min(axis=0)
# Out:
# name       naveen
# iq:            70
# percent        70
# lpa             2
# dtype: object

# %% [markdown]
# Selecting cols from a DataFrame

# %%
#single col
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
#multiple cols
movies[['title_x','actors','year_of_release']]
# Out:
#                                    title_x  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1624                 Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh
# 1627                                 Daaka
# 1628                              Humsafar
#
#                                                  actors  year_of_release
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...             2019
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...             2019
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...             2019
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...             2019
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...             2018
# ...

# %%
movies.rename(columns={'title_x':'movie_name'},inplace=True)

# %%
print(movies)
# Out:
#                                 movie_name     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
student_dict={
    'name':['nitish','jitu','ankit','amit','ankita','namita'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,40,36],
    'package':[10,7,8,9,10,8]
}

student_info=pd.DataFrame(student_dict)
print(student_info)
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %% [markdown]
# Selecting data from Dataframes
#
# .iloc-searches using index positions
#
# .loc - searches using index labels

# %%
#single_row
movies.iloc[0:5]
# Out:
#                              movie_name    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                  movie_name    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
student_info
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
student_info.loc['nitish':'jitu']
# Out:
# Empty DataFrame
# Columns: [name, iq, marks, package]
# Index: []

# %% [markdown]
# Selecting rows and cols

# %%
movies.iloc[0:3,0:3]
# Out:
#                              movie_name    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'movie_name':'poster_path']
# Out:
#                              movie_name    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# Filtering a Dataframe

# %%
bollywood=pd.read_csv('batsman_runs_ipl.csv')

# %%
diabetes=pd.read_csv('diabetes.csv')

# %%
ipl=pd.read_csv('ipl.csv')

# %%
batsman_run=pd.read_csv('batsman_runs_ipl.csv')

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#find all ipl final winners
mask=ipl['MatchNumber']=='Final'
ipl[mask]
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
mask=ipl['MatchNumber']=='Final'
new_df=ipl[mask]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#find all the winning teams
ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how many super over finishes have occured
print(f"Total super overes are {ipl[ipl['SuperOver']=='Y'].shape[0]}")
# Out:
# Total super overes are 14

# %%
#how many matches has csk won in kolkata
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
#toss winner is match winner in percentage
print(f"toss winner is match winner is arround {(ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]/ipl.shape[0])*100} %")
# Out:
# toss winner is match winner is arround 51.473684210526315 %

# %%
#movies with rating higer than 8 and votes>10000

movies[(movies['imdb_rating']>8) & (movies['imdb_votes']>10000)]
# Out:
#                        movie_name     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
#Action movies with rating higer than 7.5
mask1=movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask2=movies['imdb_rating']>7.5

movies[mask1 & mask2]
# Out:
#                          movie_name    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
#how to add new columns

movies['Country']='India'
movies.head()
# Out:
#                              movie_name    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#from existing columns
movies.dropna(inplace=True)

# %%
movies['lead actor']=movies['actors'].str.split('|').apply(lambda x:x[0])

# %%
movies
# Out:
#                    movie_name     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#astype,basically it will change the value of given type 

ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season']=ipl['Season'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# More important function

# %%
#value_counts(sries and dataframe)
marks=pd.DataFrame([[100,80,10],
                    [90,70,7],
                    [120,100,14],
                    [80,70,14],
                    [80,70,14]],columns=['iq','marks','package'])
marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.value_counts() # counts rows frequency
# Out:
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
#find which player has won  most potm -> in the finals and qualifiers
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
#Toss decision plot

ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#how many matches each team has played
ipl['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl['Team2'].value_counts()
# Out:
# Team2
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Punjab Kings                    10
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
#total matches each teams played 
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
student_dict
# Out:
# {'name': ['nitish', 'jitu', 'ankit', 'amit', 'ankita', 'namita'],
#  'iq': [100, 90, 120, 80, 0, 0],
#  'marks': [80, 70, 100, 50, 40, 36],
#  'package': [10, 7, 8, 9, 10, 8]}

# %%
movies.sort_values('title_y',ascending=False)
# Out:
#                movie_name    imdb_id  \
# 1623             Zubeidaa  tt0255713
# 1224         Zinda (film)  tt0488906
# 560       Zid (2014 film)  tt4228746
# 1312                Zeher  tt0451983
# 1035             Yuvvraaj  tt1105747
# ...                   ...        ...
# 886   Aakrosh (2010 film)  tt1708453
# 1055             68 Pages  tt1151299
# 1135        36 China Town  tt0477252
# 912              3 Idiots  tt1187043
# 1039     1971 (2007 film)  tt0983990
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1224  https://upload.wikimedia.org/wikipedia/en/thum...
# 560   https://upload.wikimedia.org/wikipedia/en/thum...
# 1312  https://upload.wikimedia.org/wikipedia/en/c/ce...
# 1035  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 886   https://upload.wikimedia.org/wikipedia/en/thum...
# 1055  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release','title_y'])
# Out:
#                         movie_name     imdb_id  \
# 1575                   Aalavandhan   tt0294264
# 1579           Ajnabee (2001 film)   tt0278291
# 1578               Aks (2001 film)   tt0289845
# 1581                  Aśoka (film)   tt0249371
# 1588                  Daman (film)   tt0273164
# ...                            ...         ...
# 96                Raid (2018 film)   tt7363076
# 116                          Sanju   tt6452574
# 123   Satyameva Jayate (2018 film)   tt8202612
# 37               Article 15 (film)  tt10324144
# 11                       Gully Boy   tt2395469
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# 1581  https://upload.wikimedia.org/wikipedia/en/thum...
# 1588  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#rank(series)
batsman_run['batting_rank']=batsman_run['batsman_run'].rank(ascending=False)
batsman_run.sort_values('batting_rank')
# Out:
#            batter  batsman_run  batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %%
#sort_index(series and dataframe)
marks={
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}
marks_series=pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks_series.sort_index(ascending=False)
# Out:
# science     89
# maths       67
# hindi      100
# english     57
# dtype: int64

# %%
movies.sort_index(ascending=False).head(5)
# Out:
#                    movie_name    imdb_id  \
# 1623                 Zubeidaa  tt0255713
# 1621                  Tum Bin  tt0290326
# 1607  Nayak (2001 Hindi film)  tt0291376
# 1601         Maya (2001 film)  tt0299027
# 1600                   Kasoor  tt0272688
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
# 1621              https://en.wikipedia.org/wiki/Tum_Bin
# 1607  https://en.wikipedia.org/wiki/Nayak_(2001_Hind...
# 1601     https://en.wikipedia.org/wiki/Maya_(2001_film)
# 1600               https://en.wikipedia.org/wiki/Kasoor
#
# ...

# %%
#set_index(dataframe)->inplace
batsman_run.set_index('batter',inplace=True)
batsman_run
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
#reset_index(series+dataframe)->drop parameter
batsman_run.reset_index()
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
#how to replace existing index without loosing
batsman_run.reset_index().set_index('batting_rank')
# Out:
#                       batter  batsman_run
# batting_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
#series to dataframe using reset_index
marks_series.reset_index()
# Out:
#      index    0
# 0    maths   67
# 1  english   57
# 2  science   89
# 3    hindi  100

# %%
#rename(data frame)->index
movies.rename(columns={'imdb_id':'imdb','poster_path':'link'},inplace=True)
movies
# Out:
#                    movie_name        imdb  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                                    link  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies
# Out:
#                    movie_name        imdb  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                                    link  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#unique(series)
ipl['Season'].unique()
# Out:
# ['2022', '2021', '2020/21', '2019', '2018', ..., '2012', '2011', '2009/10', '2009', '2007/08']
# Length: 15
# Categories (15, object): ['2007/08', '2009', '2009/10', '2011', ..., '2019', '2020/21', '2021', '2022']

# %%
#nunique(series and dataframe) -> it does not count nan ->dropna parameter
ipl['Season'].nunique()
# Out:
# 15

# %%
#isnull(series+dataframe)
student_info['name'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: name, dtype: bool

# %%
#notnull(series+dataframe)
students['name'].notnull()
# Out:
# 0    True
# 1    True
# 2    True
# Name: name, dtype: bool

# %%
#hasnas(series+dataframe) for missing value 
students['name'].hasnans
# Out:
# False

# %%
student_info
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
student_info.isnull()
# Out:
#     name     iq  marks  package
# 0  False  False  False    False
# 1  False  False  False    False
# 2  False  False  False    False
# 3  False  False  False    False
# 4  False  False  False    False
# 5  False  False  False    False

# %%
student_info.notnull()
# Out:
#    name    iq  marks  package
# 0  True  True   True     True
# 1  True  True   True     True
# 2  True  True   True     True
# 3  True  True   True     True
# 4  True  True   True     True
# 5  True  True   True     True

# %%
student_info
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %% [markdown]
# dropna(series+dataframe)->how parameter -> works loke or
# it will remove all missing values in both series and dataframe it will remove the missing value row wise

# %%
student_info.dropna(how='all')#all value nan then
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
#for specific row
student_info.dropna(subset=['name'])
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
#for two or more specific value
student_info.dropna(subset=['name','marks'])
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
#fillna (series+Dataframe)
student_info['name'].fillna('unknown').hasnans#it will just fill the value
# Out:
# False

# %%
#dropduplicate(series+dataframe)->work like and->duplicate
student_info.drop_duplicates(keep='last')
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
#find the last match played by virat kohi in delhi
ipl['all_players']=ipl['Team1Players']+ipl['Team2Players']
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
def did_kohli_play(players_list):
    return 'V Kohli' in players_list

# %%
ipl['did_kohli_play']=ipl['all_players'].apply(did_kohli_play)
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies=pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl[(ipl['City']=='Delhi') & (ipl['did_kohli_play']==True)].drop_duplicates(subset=['City','did_kohli_play'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_kohli_play
# 208           True
#
# [1 rows x 22 columns]

# %%
#drop(both series+ dataframe)
temp=pd.Series([12,23,34,90,45,23,342,334,4556,90])
temp
# Out:
# 0      12
# 1      23
# 2      34
# 3      90
# 4      45
# 5      23
# 6     342
# 7     334
# 8    4556
# 9      90
# dtype: int64

# %%
temp.drop(index=[0])
# Out:
# 1      23
# 2      34
# 3      90
# 4      45
# 5      23
# 6     342
# 7     334
# 8    4556
# 9      90
# dtype: int64

# %%
student_info
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 1    jitu   90     70        7
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
student_info.drop(columns=['iq','marks'])
# Out:
#      name  package
# 0  nitish       10
# 1    jitu        7
# 2   ankit        8
# 3    amit        9
# 4  ankita       10
# 5  namita        8

# %%
student_info.drop(index=[1])
# Out:
#      name   iq  marks  package
# 0  nitish  100     80       10
# 2   ankit  120    100        8
# 3    amit   80     50        9
# 4  ankita    0     40       10
# 5  namita    0     36        8

# %%
student_info.set_index('name').drop(index=['nitish','jitu'])
# Out:
#          iq  marks  package
# name
# ankit   120    100        8
# amit     80     50        9
# ankita    0     40       10
# namita    0     36        8

# %%
#apply (series and dataframe) it works row wise
points_df=pd.DataFrame({
    '1st point':[(3,4),(4,5),(0,0),(6,8),(4,4),(5,5)],
    '2nd point':[(1,2),(2,3),(0,6),(4,5),(2,3),(3,1)]
})

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)    (1, 2)
# 1    (4, 5)    (2, 3)
# 2    (0, 0)    (0, 6)
# 3    (6, 8)    (4, 5)
# 4    (4, 4)    (2, 3)
# 5    (5, 5)    (3, 1)

# %%
def eucliden(row):
    pt_A=row['1st point']
    pt_B=row['2nd point']

    return ((pt_A[0]-pt_B[1])**2+(pt_A[1]-pt_B[1])**2)**0.5

# %%
points_df.apply(eucliden,axis=1)
# Out:
# 0    2.236068
# 1    2.236068
# 2    8.485281
# 3    3.162278
# 4    1.414214
# 5    5.656854
# dtype: float64

# %%
points_df['distance']=points_df.apply(eucliden,axis=1)
points_df
# Out:
#   1st point 2nd point  distance
# 0    (3, 4)    (1, 2)  2.236068
# 1    (4, 5)    (2, 3)  2.236068
# 2    (0, 0)    (0, 6)  8.485281
# 3    (6, 8)    (4, 5)  3.162278
# 4    (4, 4)    (2, 3)  1.414214
# 5    (5, 5)    (3, 1)  5.656854

# %%
titanic=pd.read_csv('Titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# shape of the data

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# Random overview of data

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 629          630         0       3
# 200          201         0       3
# 206          207         0       3
# 160          161         0       3
# 715          716         0       3
#
#                                            Name   Sex   Age  SibSp  Parch  \
# 629                    O'Connell, Mr. Patrick D  male   NaN      0      0
# 200              Vande Walle, Mr. Nestor Cyriel  male  28.0      0      0
# 206                  Backstrom, Mr. Karl Alfred  male  32.0      1      0
# 160                    Cribb, Mr. John Hatfield  male  44.0      0      1
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen  male  19.0      0      0
#
#       Ticket     Fare  Cabin Embarked
# 629   334912   7.7333    NaN        Q
# 200   345770   9.5000    NaN        S
# 206  3101278  15.8500    NaN        S
# 160   371362  16.1000    NaN        S
# 715   348124   7.6500  F G73        S

# %% [markdown]
# total overview of the data

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Is there any nullvalue

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# how does the data look mathematically ?

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Are ther duplicate values ?

# %%
titanic.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# How to the correlation between cols ?

# %%
titanic.corr
# Out:
# <bound method DataFrame.corr of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...
