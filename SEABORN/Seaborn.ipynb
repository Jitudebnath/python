# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Seaborn
# - Figure Level
# - Axis Level
#
# Main Classification
# - Relational Plot
# - Distribution Plot
# - Categorical Plot
# - Regression Plot
# - Matrix Plot
# - Multiplots

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#scatter plot -> axes level function
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
#using hue
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='sex')

# %%
sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    kind="scatter",
    hue="sex",
    style="smoker",
    size="total_bill"
)

# %%
#line plot
gap = px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
temp_df=gap[gap['country']=='India']
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
sns.lineplot(data=temp_df,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.relplot(data=temp_df,x='year',y='lifeExp',kind='line')

# %%
temp_df=gap[gap['country'].isin(['India','Pakistan','China'])]
temp_df
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
sns.relplot(kind='line',data=temp_df,x='year',y='lifeExp',hue='country')

# %%
#facet Plot
# using row and cols we can use this facet plot and it works with figure level function
#it will not work with scatterplot and lineplot
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex',row='smoker')

# %%
#line plot
sns.relplot(data=tips,
            x='total_bill',
            y='tip',
            kind='line',
            col='sex',
            row='smoker')

# %%
#col wrap 
sns.relplot(
    data=gap,
    x='lifeExp',
    y='gdpPercap',
    kind='scatter',
    col='year',
    col_wrap=4
)

# %% [markdown]
# 2 . Distribution Plots
#
# - used for univariate analysis
# - used to find out the distribution
# - Range of the obervation
# - Central Tendency
# - is the data bimodal?
# - Are there outliers?
#
# Plot under distribution plot
# - histplot
# - kdeplot
# - rugplot

# %%
#figure level function ->displot
#axes level function -> histplot -> kdeplot -> rugplot

# %%
#plotting univariate histogram
sns.histplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#displot
sns.displot(data=tips,kind='hist',x='total_bill')
plt.show()

# %%
#it's also possible to visualize the distribution of categorical variable using the logic of a histogram.
# Discrete bins are automatically set for categorical variables 
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=tips,
            kind='hist',
            x='day')
plt.show()

# %%
#hue parameter
sns.displot(data=tips,
            kind='hist',
            x='tip',
            hue='sex')
plt.show()

# %%
#element using col and row
sns.displot(data=tips,
            kind='hist',
            x='tip',
            hue='sex',
            element='step')
plt.show()

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(data=titanic,
            kind='hist',
            x='age',
            element='step',
            hue='sex')
plt.show()

# %%
#faceting using col and row
sns.displot(data=tips,
            kind='hist',
            x='tip',
            element='step',
            col='sex')
plt.show()

# %%
#kdeplot
#Rather than using discrete bins, a kde plot smooths the observations with a gaussian kernel,producing a continous density estimate
sns.kdeplot(data=tips,
            x='total_bill')
plt.show()

# %%
#hue->fill
sns.kdeplot(data=tips,
            x='total_bill',
            hue='sex',
            fill=True)
plt.show()

# %%
#Rugplot

#plot marginal distribution by drawing ticks along x and y axes.

#This function is intended to complement other plot by showing the location of individual observations in an unobtrusive way.

sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#Bivariate histogram
# a bivariate histogram bins the data within rectangle that tile the plot
# and then shows the count of observation within each reactangle with the fill color

sns.histplot(data=tips,
            x='total_bill',
            y='tip')
plt.show()

# %%
#Bivariate kdeplot
# a bivariate kde plot smothes the (x,y) observations witha 2D gaussian
sns.kdeplot(data=tips,x='total_bill',y='tip')
plt.show()

# %% [markdown]
# 2.Matrix plot
# - Heatmap
# - Clustermap

# %%
#Heatmap
#plot rectangular data as a color-encoded matrix
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
temp=gap.pivot(index='country',columns='year',values='lifeExp')
plt.figure(figsize=(10,10))
sns.heatmap(temp,cmap='viridis') #axes level function
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#annot
europe=gap[gap['continent']=='Europe'].pivot(index='country',columns='year',values='lifeExp')
plt.figure(figsize=(10,10))
sns.heatmap(europe,annot=True,linewidths=0.5,cmap='viridis')
plt.show()

# %%
#clustermap

#plot a matrix dataset as a hierarchically-clustered heatmap .
#This function reqires scipy to be available

px.data.iris()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]],cmap='viridis')
plt.show()

# %% [markdown]
# Categorical Plots
#
# Categorical Scatter Plot
# - Stripplot
# - Swarmplot
#
# Categorical Distribution Plots
# - Boxplot
# - Violinplot
#
# Categorical Estiman Plot -> for central tendency
# - Barplot
# - Pointplot
# - Countplot
#
# Figure level function -> catplot

# %%
#Strip plot
sns.stripplot(data=tips,x='day',y='total_bill')#use jitter for cancel noise 
plt.show()

# %%
#using catplot , we can control jitter value here
sns.catplot(data=tips,x='day',y='total_bill',kind='strip',jitter=0.2,hue='sex')
plt.show()

# %%
#swarmplot
sns.catplot(data=tips,x='day',y='total_bill',kind='swarm',hue='sex')
plt.show()

# %% [markdown]
# BoxPlot
#
# - A box plot (also called a box and whisker plot) is a standardized visual graph that displays the distribution, variation, and outliers of numerical data

# %%
# Box plot
sns.boxplot(data=tips,x='day',y='total_bill')
plt.show()

# %%
#using catplot
sns.catplot(data=tips,x='day',y='total_bill',kind='box')
plt.show()

# %%
#hue
sns.boxplot(data=tips,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# Violin Plot = (boxplot+kdeplot)

# %%
#violinplot
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips,x='day',y='total_bill',hue='sex')
plt.show()

# %% [markdown]
# Barplot
#
# A barplot (or bar chart) is a graphical display of data using rectangular bars where the length or height of the bar is proportional to the value it represents

# %%
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker')
plt.show()

# %% [markdown]
# when there are multiple observation in each category , it also use bootstraping to compute a confidence interval around the estimate ,which  is plotted using error bars

# %%
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker',ci=None)
plt.show()
# Out:
# C:\Users\jitud\AppData\Local\Temp\ipykernel_5724\2059281126.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker',ci=None)

# %%
#pointplot
sns.pointplot(data=tips,x='sex',y='total_bill',hue='smoker')
plt.show()

# %%
sns.pointplot(data=tips,x='sex',y='total_bill',hue='smoker',ci=None)
plt.show()
# Out:
# C:\Users\jitud\AppData\Local\Temp\ipykernel_5724\4137220718.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(data=tips,x='sex',y='total_bill',hue='smoker',ci=None)

# %% [markdown]
# CountPlot
#
# A countplot is a categorical bar chart that visually displays the frequency (or count) of observations in each category

# %%
#Count plot use for categorical value
sns.countplot(data=tips,x='sex',hue='day')
plt.show()

# %%
#faceting using catplot
sns.catplot(data=tips,x='sex',y='total_bill',col='smoker',kind='box',row='time')
plt.show()

# %% [markdown]
# Regression Plots
# - regplot
# - Implot
#
# In the simplest invocation,both function draw a scatterplot of two variables,x and y, and then fit the regression model y~x and plot the resulting regrression line and a 95% confidence for that regression

# %%
#regplot is a axes level function 
sns.regplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
#lmplot
sns.lmplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')
plt.show()

# %%
#residplot
sns.residplot(data=tips,x='total_bill',y='tip')
plt.show()

# %% [markdown]
# A second way to plot facet plot -> facetgrid

# %%
sns.catplot(data=tips,x='sex',y='total_bill',kind='violin',col='day',row='time')
plt.show()

# %%
g=sns.FacetGrid(data=tips,col='day',row='time')
g.map(sns.violinplot,'sex','total_bill')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Plotting Pairwise Relationship (pairgrid vs pariplot)

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris,hue='species')
plt.show()

# %%
#pairGrid
p=sns.PairGrid(data=iris)
p.map(sns.scatterplot)
plt.show()

# %%
#map_diag -> map_offdiag
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
plt.show()

# %%
#we can use variaties of plots using pairgrid
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)
plt.show()

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)
plt.show()

# %%
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)
plt.show()

# %% [markdown]
# JointGrid and JointPlot

# %%
sns.jointplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='hist',hue='sex')
plt.show()

# %%
g=sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.boxplot)
plt.show()

# %% [markdown]
# Utility Functions

# %%
# Get dataset names
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']
